# %% [markdown]
# #### Environement Setup

# %%
# !sudo apt-get install python3.8

# %%
## Python problem resolution :
# !sudo apt-get install python3.8
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1
# !sudo apt install python3.8-distutils
# !wget https://bootstrap.pypa.io/get-pip.py
# !sudo python3.8 get-pip.py

# %%
# !sudo apt-get install python3-tk
from tkinter import dialog

# %%
# !pip install sentencepiece
# !pip install tensorflow

# %%
# !pip install torch
# !pip install accelerate -U
# !pip install pygments --upgrade
# !pip install -U spacy
# !pip install datasets
# !python -m spacy download en_core_web_sm
# !pip install wandb
# !pip install transformers==4.13.0
# !pip install nltk
# !pip install rouge_score
# !pip install bert_score
# !pip install py7zr
# !pip install metrics
# !pip install scikit-learn
# !pip install pysentimiento

# %% [markdown]
# #### Mount drive and get Data

# %%
import torch
torch.cuda.is_available()

# %%
import nltk
nltk.download('punkt')

# %%
# !git clone https://sanu2a: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@github.com/sanu2a/DeepThougt.git

# %%
# Download BLEURT checkpoint
# !wget https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip

# Unzip BLEURT checkpoint and remove the zip file
# !unzip -q BLEURT-20.zip && rm BLEURT-20.zip

# Move the unzipped content to the specified directory
# !mv BLEURT-20 /content/DeepThougt/SICK_Summariz/utils/bleurt/bleurt_checkpoint
# Out:
# --2024-02-02 11:25:19--  https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.2.207, 74.125.137.207, 2607:f8b0:4023:c0d::cf
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.2.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2140294207 (2.0G) [application/octet-stream]
# Saving to: ‘BLEURT-20.zip’
#
# BLEURT-20.zip       100%[===================>]   1.99G   105MB/s    in 20s
#
# 2024-02-02 11:25:39 (104 MB/s) - ‘BLEURT-20.zip’ saved [2140294207/2140294207]

# %%
## Mount the drive to get Data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
## TRY to download the data from the link in your laptop
# then load it to your google drive in colab notebook or you can change the path if u want
## FOR COMET DATA
# !rm -r '/content/DeepThougt/SICK_Summariz/data/COMET_data'
source_path = '/content/drive/MyDrive/Data/COMET_data'
destination_path = '/content/DeepThougt/SICK_Summariz/data/COMET_data'
shutil.copytree(source_path, destination_path)
# !rm -r '/content/DeepThougt/SICK_Summariz/data/DialogSum_Data'
source_path = '/content/drive/MyDrive/Data/DialogSum_Data'
destination_path = '/content/DeepThougt/SICK_Summariz/data/DialogSum_Data'
shutil.copytree(source_path, destination_path)
# Out:
# '/content/DeepThougt/SICK_Summariz/data/DialogSum_Data'

# %% [markdown]
# #### Train the model and save checkpoints

# %%
# %cd /content/DeepThougt/SICK_Summariz/src
# Out:
# /content/DeepThougt/SICK_Summariz/src

# %%
## with sentiment injection
# !python3 train_summarization_context.py --finetune_weight_path="./new_weights_sick" --best_finetune_weight_path="./new_weights_sick_best" --dataset_name="dialogsum" --use_paracomet=True --model_name="facebook/bart-large-xsum" --relation "xIntent" --epoch=1 --use_sentence_transformer True --emotion=True --subset_size 50 --train_batch_size 1

# %%
import os
import shutil
def zip_and_save_checkpoints(checkpoint_dir, zip_filename, output_path="/content/drive/MyDrive"):
    # Make sure the checkpoint directory exists
    if os.path.exists(checkpoint_dir):
        # Create a zip file with the contents of the checkpoint directory
        zip_path = os.path.join(output_path, zip_filename)
        shutil.make_archive(zip_path, 'zip', checkpoint_dir)
        print(f"Checkpoints zipped and saved to {zip_path}")
    else:
        print("Checkpoint directory not found.")

# %%
checkpoint_dir = "./new_weights_sick_best"
zip_filename1 = "./new_weights_sick_1ep_diagsum"
output_path = "/content/drive/MyDrive"
zip_and_save_checkpoints(checkpoint_dir, zip_filename1, output_path)

# %% [markdown]
# #### Inference

# %%
import zipfile
import os

path = "/content/drive/MyDrive/new_weights_sick_1ep_diagsum.zip"
unzip_path = "/content/new_weights_sick_1epdiagsum"

os.makedirs(unzip_path, exist_ok=True)

# Unzip the checkpoints
with zipfile.ZipFile(path, 'r') as zip_ref:
    zip_ref.extractall(unzip_path)

# %%
# !python inference.py --dataset_name dialogsum --use_paracomet True --relation "xIntent" --model_checkpoint "/content/new_weights_sick_1epdiagsum" --num_beams 5 --test_output_file_name "/content/drive/MyDrive/diagsumresults.txt"
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 2024-02-02 11:30:30.178260: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-02 11:30:31.191603: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-02 11:30:32.820722: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading: 100% 999/999 [00:00<00:00, 5.06MB/s]
# Downloading: 100% 515M/515M [00:09<00:00, 55.4MB/s]
# Downloading: 100% 295/295 [00:00<00:00, 1.76MB/s]
# Downloading: 100% 824k/824k [00:00<00:00, 7.52MB/s]
# Downloading: 100% 1.03M/1.03M [00:00<00:00, 6.19MB/s]
# ...
